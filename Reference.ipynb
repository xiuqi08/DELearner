# %%
import pandas as pd
import numpy as np
import glob
import os
import re

# %%
confs = ["ACL","ICDM","ICML","KDD","NIPS","SIGMOD","SIGIR"]
dic = {}
for conf in confs:
    try:
        lines = []
        for f in glob.glob(os.path.join("./","TXT",conf+"*.txt")):
            print(f)
            for line in open(f,encoding="utf-"):
                lines.append(line)
        dic[conf] = lines
    except:
        pass
dic
# Out:
# ./TXT/ACL.txt
# ./TXT/ICDM5.txt
# ./TXT/ICDM4.txt
# ./TXT/ICDM6.txt
# ./TXT/ICDM3.txt
# ./TXT/ICDM2.txt
# ./TXT/ICDM1.txt
# ./TXT/ICML2.txt
# ./TXT/ICML.txt
# ./TXT/KDD6.txt
# ./TXT/KDD4.txt
# ./TXT/KDD5.txt
# ./TXT/KDD1.txt
# ./TXT/KDD2.txt
# ./TXT/KDD3.txt
# ./TXT/NIPS5.txt
# ./TXT/NIPS4.txt
# ./TXT/NIPS6.txt
# ./TXT/NIPS3.txt
# ./TXT/NIPS2.txt
# ./TXT/NIPS1.txt
# ./TXT/SIGMOD.txt
# ./TXT/SIGMOD1.txt
# ./TXT/SIGMOD2.txt
# ./TXT/SIGIR2.txt
# ./TXT/SIGIR3.txt
# ./TXT/SIGIR1.txt
# {'ACL': ['\ufeffFN Clarivate Analytics Web of Science\n',
#   'VR 1.0\n',
#   'PT B\n',
#   'AU Klein, D\n',
#   '   Manning, CD\n',
#   'AF Klein, D\n',
#   '   Manning, CD\n',
#   'GP ACL\n',
#   'TI Accurate unlexicalized parsing\n',
#   'SO 41ST ANNUAL MEETING OF THE ASSOCIATION FOR COMPUTATIONAL LINGUISTICS,\n',
#   '   PROCEEDINGS OF THE CONFERENCE\n',
#   'LA English\n',
#   'DT Proceedings Paper\n',
#   'CT 41st Annual Meeting of the Association-for-Computational-Linguistics\n',
# ...

# %%
dic['KDD']
# Out:
# ['\ufeffFN Clarivate Analytics Web of Science\n',
#  'VR 1.0\n',
#  'PT B\n',
#  'AU Xiao, ZH\n',
#  '   Wu, YH\n',
#  '   Guan, ZQ\n',
#  'AF Xiao, Zhi-hong\n',
#  '   Wu, Yao-hui\n',
#  '   Guan, Zong-qi\n',
#  'BE Luo, Q\n',
#  '   Gong, M\n',
#  '   Xiong, F\n',
#  '   Yu, F\n',
#  'TI A new private multi-channel UWB MAC protocol design for distributed\n',
#  '   network\n',
#  'SO FIRST INTERNATIONAL WORKSHOP ON KNOWLEDGE DISCOVERY AND DATA MINING,\n',
#  '   PROCEEDINGS\n',
#  'LA English\n',
#  'DT Proceedings Paper\n',
#  'CT 1st International Workshop on Knowledge Discovery and Data Mining\n',
#  'CY JAN 23-24, 2008\n',
#  'CL Adelaide, AUSTRALIA\n',
#  'SP Univ Adelaide, Inst Comp Sci, Social Informat & Telecommun Engn, E Forensics, Ningbo Univ, Wuhan Univ Sci & Technol, Zhongan Branch, Assoc Comp Mach\n',
# ...
